# %% [markdown]
# ### First Lecture (or two)
#
# 1. Everyone set up Google account, and get to Colab website
#
# 1. Everyone install Chrome on your machine
#
# 1. Get everyone set up with Google Drive, and uploading files there.  Our basic workflow will be
#   - Upload course *.ipynb files to Drive at the start of each week.  There should be just three of these
#   - Step through this process with everyone, probably using the projector
#
# 1. Explain what Colab is, a full machine existing in the cloud
#   - Have the students open files in Colab
#   - Probably want to repeat this process 2 or 3 times (uploading *.ipyng to Drive and opening in Colab), so everyone get's used to it.
#
# 1. Go through getting files from Drive into Colab
#   - Have to give Colab permission to access Drive
#   - Then practice getting library files and downloading them
#
# 1. Everyone open this notebook to install Visual Python
#   - Install Visual Python by going to Chrome and adding this extension
#
#     https://chrome.google.com/webstore/detail/visual-python-for-colab/ccmkpknjfagaldcgidgcipbpdipfopob
#
#   - Installation help:
#
#     https://visual-python.gitbook.io/docs/getting-started/how-to-install
#
# 1. Open Visual Python
#   - This is going to be located where your Chrome extensions are. Look for a tiny "puzzle piece" icon in the top right of Chrome.
#   ![](https://drive.google.com/uc?export=view&id=1HGSH6ht3BwGiPRmovkSc15ClGZbrrq0Z)
#   - Click on this and select "Visual Python for Colab"
#
#
#   - Or, you may see a little yellow button in the top right
#
#     ![](https://drive.google.com/uc?export=view&id=1-fG2aqwifu6ZhYfLxm-xcBgDioWnrt9v)
#
#     If you see this little yellow button, click on it, to open the Visual Python helper

# %% [markdown]
# Orient on how to use a notebook
# - basic printing,
# - text versus code (really make sure they understand this)
# - maybe load some data and plot it, maybe from one of the stored csv file

# %%
# instructions to do a few simple things with visual python...
# Out:
# 4
