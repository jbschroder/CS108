# %%
# Visual Python: Data Analysis > Import
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Pandas data prints out nicely to the screen

# %%
# Visual Python: Data Analysis > File
vp_df = pd.read_csv('./sample_csv/iris.csv')
vp_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# Visual Python: Data Analysis > File
vp_df = pd.read_csv('./sample_csv/fish.csv')
vp_df
# Out:
#           Type  Length      Depth         Kg
# 0         tuna   55.46  13.240930   8.631268
# 1         tuna   72.07  17.671346  19.288996
# 2         tuna   62.84  15.635367  13.140561
# 3         tuna   72.79  18.440841  19.669098
# 4         tuna   76.63  19.137488  23.021797
# ...        ...     ...        ...        ...
# 1495  mackerel   41.06   8.252645   1.330602
# 1496  mackerel   41.77   8.590338   1.476314
# 1497  mackerel   35.25   7.131067   0.851601
# 1498  mackerel   36.65   7.519112   1.243252
# 1499  mackerel   32.33   6.579096   0.789629
#
# [1500 rows x 4 columns]

# %% [markdown]
# How to access columns in Pandas -- it's not quite like array slicing

# %%
vp_df.columns
# Out:
# Index(['Type', 'Length', 'Depth', 'Kg'], dtype='object')

# %%
vp_df[['Type','Length']]
# Out:
#           Type  Length
# 0         tuna   55.46
# 1         tuna   72.07
# 2         tuna   62.84
# 3         tuna   72.79
# 4         tuna   76.63
# ...        ...     ...
# 1495  mackerel   41.06
# 1496  mackerel   41.77
# 1497  mackerel   35.25
# 1498  mackerel   36.65
# 1499  mackerel   32.33
#
# [1500 rows x 2 columns]

# %%
all_tuna = vp_df[vp_df['Type'] == 'tuna']

# %%
all_tuna['Depth'].plot(kind='line')
# Out:
# <AxesSubplot: >
