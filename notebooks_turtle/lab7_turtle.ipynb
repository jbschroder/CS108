# %% [markdown]
# ## Turtle Lab 5: Advanced if/else and Moving the turtle with advanced if/else
# Lecture file: `05_Lists_Part1.ipynb`

# %% [markdown]
# ### Learning Goals
#
# 1. Learn about lists
#     - Lists are a special type of variable, which holds multiple things
#     - Lists let you take a bunch of things and group them together inside of one big container
# 2. Learn: Lists can have duplicate items
# 3. Learn: Lists can contain any type of variable
#     - The first item in a list could be a number
#     - The second item in a list could be a word, and so on

# %% [markdown]
# 4. Continue using and learning about conditionals (if/else) statements
#     - Continue using `not`, `<`, `>`, `<=`, `>=`, `==` inside of if/else
#     - For example, `if (not x == 0):` will let you run code whenever x is 0

# %% [markdown]
# 5. Understand these ideas in the context of a turtle object
#     - The turtle uses a list to control and store where to move
#
#     - For instance, the list
#
#           [(0,0), (1,0), (2,0)]
#
#       represents starting at `(0,0)` and then moving two squares to the right.
#
#       This list would be generated by calling
#
#           turtle.move_right()
#           turtle.move_right()
#
#     - Generate and understand this list

# %% [markdown]
# ### <span style="color:blue"> First </span>
#
# <span style="color:blue"> We have some **house cleaning** to do before we can start. </span>
# 1. <span style="color:blue"> We download some code(`turtle_generator.py`) to define how our turtle can move around </span>
# 2. <span style="color:blue"> We pull the `turtle_generator` code into this notebook with an `import` command </span>

# %%
# House cleaning part 1
from urllib.request import urlretrieve
(file, message) = urlretrieve('https://raw.githubusercontent.com/jbschroder/CS108/main/notebooks_turtle/turtle_generator.py', 'turtle_generator.py')
print("You downloaded the file " + file)

# House cleaning part 2
from turtle_generator import turtle_generator
# Out:
# You downloaded the file turtle_generator.py

# %% [markdown]
# ### Using what you learned in the lecture video, you will now experiment with more advanced if statements (conditionals)
#
# ### Task: Run the below cell.  Then add a new fruit to the list, and run again.
# - For instance,
#
#   `fruit = ["apple", "banana", "grape", "orange"]`
#
#   would add a new fruit.  Make sure you add a new fruit that isn't an orange.

# %%
fruit = ["apple", "banana", "grape"]
print(fruit)
# Out:
# ['apple', 'banana', 'grape']

# %% [markdown]
# ### Task: See how lists can contain really just about anything.  Run the below cell.  Then add a new number and a new word to the list, and run again.
#
# - For instance,
#
#   `fruitAndStuff = ["apple", 3.14, 55, "banana", "grape", -22.14, "some words!"]`
#
#   would add new entries to the list.  Make sure you add new items that aren't `-22.14` or `some words!` to the list.
#
# - You can experiment by adding new entries two or three times, running the cell each time you add new entries

# %%
fruitAndStuff = ["apple", 3.14, 55, "banana", "grape"]
print(fruitAndStuff)
# Out:
# ['apple', 3.14, 55, 'banana', 'grape']

# %% [markdown]
# ### Task: In the below cell, create your own list.
# - Create a list with four items in it.  Make sure that at least one of the items is a number and one of the items is a string
# - Remember string just means a word or combination of letters, like "hello" or "rjklomo"
# - Then, print your list to the screen, and run the below cell

# %%
# insert code here

# %% [markdown]
# ### <span style="color:blue"> Now, we can get started with the turtle part of the lab! </span>
#
# <span style="color:blue"> First, we have to create a new turtle.</span>
#
# - <span style="color:blue"> We use the _maze_ parameter again </span>
# - <span style="color:blue"> Remember, that we can give `turtle_generator()` values inside the parentheses that tell `turtle_generator()` what to do </span>
# - <span style="color:blue"> This is the essence of a **parameter**, values that you give something (like `turtle_generator()`) that tell it what to do </span>
#
# <span style="color:blue"> Second, at the bottom of the cell, we take a look at our turtle and find that it's at location `(0,0)`, with a simple maze and pond </span>

# %%
my_maze = 1
turtle = turtle_generator( maze_number=my_maze )

turtle.show_starting_position()

# %% [markdown]
# ### <span style="color:blue"> Next, we have to tell our turtle to get ready for a trip with `turtle.start_new_journey()` </span>

# %%
turtle.start_new_journey()

# %% [markdown]
# ### We will now experiment with more advanced conditionals to control the turtle movement
#
# ### Task: Run the four below cells about where the pond is
# - What are these lines of code telling you?

# %%
print(turtle.is_pond_below())
# Out:
# False

# %%
print(turtle.is_pond_above())
# Out:
# True

# %%
print(turtle.is_pond_to_left())
# Out:
# False

# %%
print(turtle.is_pond_to_right())
# Out:
# True

# %% [markdown]
# ### These lines of code are telling you where the pond is.  The pond is to the right, and above!
#
# ----------
#
# ### Task:  Run the four below cells about where the path is.
# - What are these lines of code telling you?

# %%
print(turtle.is_path_below())
# Out:
# False

# %%
print(turtle.is_path_above())
# Out:
# False

# %%
print(turtle.is_path_to_left())
# Out:
# False

# %%
print(turtle.is_path_to_right())
# Out:
# True

# %% [markdown]
# ### These lines of code are telling you where the maze path is.  The maze path is to the left.
#
# -----------
#
# ### Let's try to use these True and False values in conditionals
# - Use True and False to move the turtle automatically towards the pond
#
# ### Task: Run the below cell
# - Observe how the True and False values control which print statement happens

# %%
if True:
    print("I want to move the turtle right")
elif False:
    print("I want to move the turtle left")
# Out:
# I want to move the turtle right

# %% [markdown]
# ### Consider: What if we replace the `True` above with `turtle.is_path_to_right()` and the `False` above with `turtle.is_path_above()`?
# - Remember `turtle.is_path_to_right()` actually equals `True` !
# - Remember `turtle.is_path_above()` actually equals `False` !
#
# #### --> We can use `turtle.is_path_to_right()` and `turtle.is_path_above()` in cominbation with if statements to automatically move the turtle!
#
# ------
#
# ### <span style="color:blue"> Task: Replace the `True` and `False` below with `turtle.is_path_to_right()` and `turtle.is_path_above()` respectively </span>
#
# ### <span style="color:blue"> Then, run the below cell once </span>

# %%
if True:
    print("Moving right")
    turtle.move_right()
elif False:
    print("Moving up")
    turtle.move_up()
# Out:
# Moving right

# %% [markdown]
# ### Task: Let's visualize your code.  Run the below cell once.
#
# ### Did you see the turtle move one square to the right?  Stop and ask if not.

# %%
turtle.watch_me_move()

# %% [markdown]
# ### <span style="color:blue"> Task:  Copy and paste the cell above with `if` and `elif` in it.  Paste this cell immediately below this cell. </span>
#
# <span style="color:blue"> You are copying a cell which should look like </span>
#
#     if turtle.is_path_to_right():
#         print("Moving right")
#         turtle.move_right()
#     elif ... some more code that you wrote ...
#         ... some more code that you wrote ...
#         ... some more code that you wrote ...
#
# ### <span style="color:blue"> Copy and paste this `if` and `elif` cell many, many times below.  Remember that each cell lets you move once.  So, copy and paste it enough times to move your turtle all the way to the pond. </span>
#
# <span style="color:blue"> You'll need about 24 or 25 cells to move your turtle all the way to the pond. </span>

# %%
# copy and paste above cell here

# %% [markdown]
# ### Task: Let's visualize your code.  Run the below cell.  Then run the below cell once.
#
# ### Did the turtle reach the pond and stay in the maze, on the path?  Stop and ask if not.

# %%
turtle.watch_me_move()

# %% [markdown]
# ### <span style="color:blue"> Task: Run the below cell.  Do you get `True` both times?  This will also indicate that you stayed on the maze path and completed the maze.  </span>
# - <span style="color:blue"> If you get any `False` message below, ask </span>

# %%
print("Did the turtle stay on the maze path?")
print(turtle.check_stayed_on_maze_path())
print("-----------")
print("Did the turtle complete the maze?")
print(turtle.check_maze_completed())
# Out:
# Did the turtle stay on the maze path?
# True
# -----------
# Did the turtle complete the maze?
# Turtle did not reach maze goal
# False

# %% [markdown]
# ### Task: Understand how to use a list to track movements.  Run the below cell.
# - Analyze and inspect the list of movements printed to the screen.
# - Observe how the turtle
#     - Moves to the right 5 times
#     - Then moves up 6 times
#     - Then moves right 7 times
#     - And finally moves up 6 times to the pond
#
# Stop and ask if you have questions about the list of movements

# %%
movements = turtle.get_movements()
print(movements)
# Out:
# [(0, 0), (1, 0)]

# %% [markdown]
# ### <span style="color:blue"> For homeworks, you will need to save your turtle simulation to a file </span>

# %%
turtle.save_everything_to_file()
# Out:
# You just saved your turtle to file at 14:52:55 on 04/12/2023
# Thank you!

# %% [markdown]
# ### The below Tasks are what you need to do, in order to submit your homework for this week

# %% [markdown]
# ### Task 1
# - Create a new notebook in CoLab
# - For each markdown cell with **blue**
#    - Copy that markdown cell to the new notebook
#    - Also copy the code cell immediately below to the new notebook
#      --> Basically, you copy all the cells that are needed to experiment with a turtle
#
#      For the 24 or 25 cells that follow some blue text, you will need to copy and paste
#      all of those cells to the new notebook
# - Don't forget to include the cell that runs `turtle.save_everything_to_file()`

# %% [markdown]
# ### Task 2
# - Double check that your new notebook is correct.
# - Go to the `Runtime` menu at the top of CoLab
#     - Choose to `Restart session and run all`
#     - If that option is not available, then choose `Run all`
# - Then, look at the output for all of your cells.  Does it look correct?  Did your turtle complete the maze successfully, and print `True` above for the `check` functions?

# %% [markdown]
# ### Homework submission
#
# - After completing this, download your notebook to `.py` file and upload this `.py` file to Canvas for the weekly homework
#
#
# - Name your homework file `hw#.py`, where `#` is the correct number for this week, for instance `hw1.py`, `hw2.py`, ...

# %% [markdown]
# ### Reminder: To download correctly, click on the `download as .py` option in Colab
# ![](https://raw.githubusercontent.com/jbschroder/CS108/main/notebooks_turtle/image_of_downloading_py_file.png)

# %%
then copy all this over to lab 7, where they combine pond and path
- then delete stuff below in lab 6 document
- in lab 7, use lists to create an action tape for printing (and/or in lab 8, maybe add more information to it, will help with debugging)

then lab8 will do intro to fcns,

# %% [markdown]
# ### Task: enter two new lines of code in the below cell
# - The first line will move your turtle to the right one square
#
#    `turtle.move_right()`
#
#
# - The second line will create the animation
#
#     `turtle.watch_me_move()`
#
# ### Then run the below cell to see the turtle move right one square

# %%
### enter two lines of code as instructed above

# %% [markdown]
# ### Next, we see what our path finding code tells us
#
# ### Task:  Run the four below cells about where the path is.
# - What are these lines of code telling you?

# %%
print(turtle.is_path_below())

# %%
print(turtle.is_path_above())

# %%
print(turtle.is_path_to_left())

# %%
print(turtle.is_path_to_right())

# %% [markdown]
# ### The path is now to the left and to the right!
#
# ### Idea: Let's try to use the `is_path_...` information to automatically move the turtle

# %% [markdown]
# ### Let's say that our goal is to find the pond automatically AND stay on the path
#
#
# ### We can combine our `is_path_...` and `is_pond_...` information to do this automatically!

# %% [markdown]
# ### We will now experiment with more advanced conditionals to control the turtle movement
#
#
# ### Task:  Run the below two cells
# - Make sure you run both the cell with `direction = ...` and the cell with  `turtle.watch_me_move()`
#
#
# #### What happens?  Why does the turtle move one square to the right?

# %%
direction = 'right'
if (direction == 'left'):
    turtle.move_left()
elif (direction == 'right'):
    turtle.move_right()

# %%
turtle.watch_me_move()

# %% [markdown]
# ### Next, we will restart our journey, which deletes all the previous moves

# %%
turtle.start_new_journey()

# %% [markdown]
# ### Task 1:  Add four new lines of code below to allow your turtle to go `down` and `up`
# - You can copy the two lines for going `left` and then modify for going `down`
# - Repeat for going `up`
#
# ### Task 2: Run the below cell multiple times, changing `direction` to direction your turtle through the maze
# - Each time you run the cell, you will generate a new animation with one new move

# %%
direction = 'right'
if (direction == 'left'):
    turtle.move_left()
elif (direction == 'right'):
    turtle.move_right()

turtle.watch_me_move()

# %% [markdown]
# ### Advanced Task
# - Repeat all of the above tasks, but for `my_maze = 2`
