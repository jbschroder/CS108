# %% [markdown]
# ### Some simple unit tests for turtle generator
#
# Test turtle leaving a trail
#
# Test turtle is_pond_* functions

# %%
import subprocess
import os
result = subprocess.run(['curl -L "https://www.unm.edu/~jbschroder/img/turtle.png" > turtle.png;'], shell=True, capture_output=True)
if( os.path.isfile('./turtle.png') == False): print("Something went wrong with downloading turtle image")
#result = subprocess.run(['curl -L "https://drive.google.com/uc?export=download&confirm=1&id=1mYq0pZwvrWFZDKw5j_ruwdEAOV887QTe" > turtle_generator.py;'], shell=True, capture_output=True)
#if( os.path.isfile('./turtle_generator.py') == False): print("Something went wrong with downloading turtle_generator code")

# %%
from turtle_generator import turtle_generator

# %%
# check not completing maze by starting somewhere else
turtle15 = turtle_generator(nx=14, ny=14, start_location=(0,0), maze_number=1,  pond_location=(12,12))
turtle15.start_new_journey()
turtle15.move_right(leave_trail=True); 
turtle15.move_right(leave_trail=True); 
turtle15.move_right(leave_trail=True); 
turtle15.move_right(leave_trail=False); 
turtle15.move_right(leave_trail=True); 
turtle15.move_up(leave_trail=True); 
turtle15.move_up(leave_trail=True); 
turtle15.move_up(leave_trail=True); 
turtle15.move_up(leave_trail=False);
turtle15.move_up(leave_trail=True); 
turtle15.move_left(leave_trail=True); 
turtle15.move_left(leave_trail=True); 
turtle15.move_left(leave_trail=False);
turtle15.move_down(leave_trail=True);

# %%
turtle15.watch_me_move()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
