# %% [markdown]
# ### Some simple unit tests for turtle generator
#
# Test turtle leaving a trail
#
# Test turtle is_pond_* functions

# %%
from urllib.request import urlretrieve
#(file, message) =urlretrieve('https://raw.githubusercontent.com/jbschroder/CS108/main/notebooks_turtle/turtle_generator.py', 'turtle_generator.py')
#print("You downloaded file " + file)

# %%
from turtle_generator import turtle_generator

# test leaving a trail
turtle1 = turtle_generator(nx=14, ny=14, start_location=(0,0), maze_number=1)
turtle1.start_new_journey()
turtle1.move_right(leave_trail=True); 
turtle1.move_right(leave_trail=True); 
turtle1.move_right(leave_trail=True); 
turtle1.move_right(leave_trail=False); 
turtle1.move_right(leave_trail=True); 
turtle1.move_up(leave_trail=True); 
turtle1.move_up(leave_trail=True); 
turtle1.move_up(leave_trail=True); 
turtle1.move_up(leave_trail=False);
turtle1.move_up(leave_trail=True); 
turtle1.move_left(leave_trail=True); 
turtle1.move_left(leave_trail=True); 
turtle1.move_left(leave_trail=False);
turtle1.move_down(leave_trail=True);

# %%
turtle1.watch_me_move()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc7bc40593afa4e61b0422176d49acbc6">
#   <div class="anim-controls">
#     <input id="_anim_sliderc7bc40593afa4e61b0422176d49acbc6" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc7bc40593afa4e61b0422176d49acbc6.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animc7bc40593afa4e61b0422176d49acbc6.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animc7bc40593afa4e61b0422176d49acbc6.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animc7bc40593afa4e61b0422176d49acbc6.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animc7bc40593afa4e61b0422176d49acbc6.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animc7bc40593afa4e61b0422176d49acbc6.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animc7bc40593afa4e61b0422176d49acbc6.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animc7bc40593afa4e61b0422176d49acbc6.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animc7bc40593afa4e61b0422176d49acbc6.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animc7bc40593afa4e61b0422176d49acbc6.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectc7bc40593afa4e61b0422176d49acbc6"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c7bc40593afa4e61b0422176d49acbc6"
#              checked>
#       <label for="_anim_radio1_c7bc40593afa4e61b0422176d49acbc6">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c7bc40593afa4e61b0422176d49acbc6"
#              >
#       <label for="_anim_radio2_c7bc40593afa4e61b0422176d49acbc6">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c7bc40593afa4e61b0422176d49acbc6"
#              >
#       <label for="_anim_radio3_c7bc40593afa4e61b0422176d49acbc6">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc7bc40593afa4e61b0422176d49acbc6";
#     var slider_id = "_anim_sliderc7bc40593afa4e61b0422176d49acbc6";
#     var loop_select_id = "_anim_loop_selectc7bc40593afa4e61b0422176d49acbc6";
#     var frames = new Array(43);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjYuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy89olMNAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAA4R0lEQ

# %%
print( turtle1.is_pond_above() )
print( turtle1.is_pond_below() )
print( turtle1.is_pond_to_right() )
print( turtle1.is_pond_to_left() )
# Out:
# True
# False
# True
# False

# %%
# Should generate not initialized error, cause you never called start_new_journey
turtle2 = turtle_generator(nx=14, ny=14, start_location=(3,4), maze_number=1,  pond_location=(12,12))
print( turtle2.is_pond_above() )
print( turtle2.is_pond_below() )
print( turtle2.is_pond_to_right() )
print( turtle2.is_pond_to_left() )
turtle1.show_starting_position()
# Out:
# Cannot set both pond_location and maze_number.  The maze_number determines the pond_location
# automatically, as the maze's goal. Ignoring user pond_location and using the maze_number's
# goal location for the pond.
# You don't have any turtles yet!
#  Try doing calling turtle.start_new_journey(), followed by some movements like
#  turtle.move_up()
# None
# You don't have any turtles yet!
#  Try doing calling turtle.start_new_journey(), followed by some movements like
#  turtle.move_up()
# None
# You don't have any turtles yet!
#  Try doing calling turtle.start_new_journey(), followed by some movements like
#  turtle.move_up()
# None
# You don't have any turtles yet!
#  Try doing calling turtle.start_new_journey(), followed by some movements like
#  turtle.move_up()
# None

# %%
turtle2 = turtle_generator(nx=14, ny=14, start_location=(3,4), maze_number=1)
turtle2.start_new_journey()
print( turtle2.is_pond_above() )
print( turtle2.is_pond_below() )
print( turtle2.is_pond_to_right() )
print( turtle2.is_pond_to_left() )
turtle2.show_starting_position()
# Out:
# True
# False
# True
# False

# %%
turtle2 = turtle_generator(nx=14, ny=14, start_location=(3,4), pond_location=(1,2))
turtle2.start_new_journey()
print( turtle2.is_pond_above() )
print( turtle2.is_pond_below() )
print( turtle2.is_pond_to_right() )
print( turtle2.is_pond_to_left() )
turtle2.show_starting_position()
# Out:
# False
# True
# False
# True

# %%
turtle2 = turtle_generator(nx=14, ny=14, start_location=(3,4), pond_location=(8,4))
turtle2.start_new_journey()
print( turtle2.is_pond_above() )
print( turtle2.is_pond_below() )
print( turtle2.is_pond_to_right() )
print( turtle2.is_pond_to_left() )
turtle2.show_starting_position()
# Out:
# False
# False
# True
# False

# %%
turtle2 = turtle_generator(nx=14, ny=14, start_location=(3,4), pond_location=(3,7))
turtle2.start_new_journey()
print( turtle2.is_pond_above() )
print( turtle2.is_pond_below() )
print( turtle2.is_pond_to_right() )
print( turtle2.is_pond_to_left() )
turtle2.show_starting_position()
# Out:
# True
# False
# False
# False

# %%
turtle2 = turtle_generator(nx=14, ny=14, start_location=(3,4), pond_location=(1,4))
turtle2.start_new_journey()
print( turtle2.is_pond_above() )
print( turtle2.is_pond_below() )
print( turtle2.is_pond_to_right() )
print( turtle2.is_pond_to_left() )
turtle2.show_starting_position()
# Out:
# False
# False
# False
# True

# %%
turtle2 = turtle_generator(nx=14, ny=14, start_location=(3,4), pond_location=(3,3))
turtle2.start_new_journey()
print( turtle2.is_pond_above() )
print( turtle2.is_pond_below() )
print( turtle2.is_pond_to_right() )
print( turtle2.is_pond_to_left() )
turtle2.show_starting_position()
# Out:
# False
# True
# False
# False

# %%
print("False False True False\n\
False False True True\n\
False False True True\n\
False True False True\n")
for start in [(0,0), (1,0), (2,0), (5,0)]:
  turtle2 = turtle_generator(nx=14, ny=14, start_location=start, maze_number=1)
  turtle2.start_new_journey()
  print(turtle2.is_path_below(), turtle2.is_path_above(), turtle2.is_path_to_right(), turtle2.is_path_to_left())
  #turtle2.show_starting_position()
# Out:
# False False True False
# False False True True
# False False True True
# False True False True
#
# False False True False
# False False True True
# False False True True
# False True False True

# %%
print("True True False False\n\
True True False False\n\
True False True False\n")
for start in [(5,1), (5,5), (5,6)]:
  turtle2 = turtle_generator(nx=14, ny=14, start_location=start, maze_number=1)
  turtle2.start_new_journey()
  print(turtle2.is_path_below(), turtle2.is_path_above(), turtle2.is_path_to_right(), turtle2.is_path_to_left())
  #turtle2.show_starting_position()
# Out:
# True True False False
# True True False False
# True False True False
#
# True True False False
# True True False False
# True False True False

# %%
print("False False True True\n\
False False True True\n\
False False True True\n\
False True False True\n")

for start in [(6,6), (7,6), (11,6), (12,6)]:
  turtle2 = turtle_generator(nx=14, ny=14, start_location=start, maze_number=1)
  turtle2.start_new_journey()
  print(turtle2.is_path_below(), turtle2.is_path_above(), turtle2.is_path_to_right(), turtle2.is_path_to_left())
  #turtle2.show_starting_position()
# Out:
# False False True True
# False False True True
# False False True True
# False True False True
#
# False False True True
# False False True True
# False False True True
# False True False True

# %%
print("True True False False\n\
True True False False\n\
True True False False\n\
True False False False\n")

for start in [(12,7), (12,8), (12,11), (12,12)]:
  turtle2 = turtle_generator(nx=14, ny=14, start_location=start, maze_number=1)
  turtle2.start_new_journey()
  print(turtle2.is_path_below(), turtle2.is_path_above(), turtle2.is_path_to_right(), turtle2.is_path_to_left())
  #turtle2.show_starting_position()
# Out:
# True True False False
# True True False False
# True True False False
# True False False False
#
# True True False False
# True True False False
# True True False False
# True False False False

# %%
# none of these positions are on the maze -- check that they are caught as incorrect positions

for start in [(2,6), (1,12), (12,1), (7,8)]:
  turtle2 = turtle_generator(nx=14, ny=14, start_location=start, maze_number=1)
  turtle2.start_new_journey()
  print(turtle2.is_path_below(), turtle2.is_path_above(), turtle2.is_path_to_right(), turtle2.is_path_to_left())
  #turtle2.show_starting_position()
# Out:
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# None None None None
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# None None None None
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# None None None None
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# Your turtle has left the maze path, so you can't ask questions about how to follow the maze path
# None None None None
