# %% [markdown]
# ## Turtle Lab 5: Advanced if/else and advanced if/else to move the turtle
# Lecture file: `04_Condtionals_Part2.ipynb`

# %% [markdown]
# ### Learning Goals
#
# 1. Review if/else statements
#     - Statements with if/else are called **conditionals**
#     - If some **condition** is met (like `x` is smaller than -2), then do something
#
#     - You these comparison operations to test for `conditions`
#         - Less than `<`
#         - Greater than `>`
#         - Less than or equal to `<=`
#         - Greater than or equal to `>=`
#         - Is Equal `==`
#
#     - Remember: if statements let you control your code by comparing values
#         - if your comparison between two values is True, then execute some particular code
#         - if your comparison between two values if False, then execute some other code

# %% [markdown]
# 2. Learn how to use `not` inside a conditional
#     - `not` allows you to test for things that are not true
#     - For example, `if (not number == 0):` will only work if `number` is not 0

# %% [markdown]
# 3. Use more advanced conditionals to control your turtle
#     - Use variables that are strings to control your turtle
#     - Remember a string is just letters and words
#     - So, we will move our turtle with statements like
#
#            if move == 'left':
#                turtle.move_up()

# %% [markdown]
# ###  First
#
# We have some **house cleaning** to do before we can start.
# 1. We download some code(`turtle_generator.py`) to define how our turtle can move around
# 2. We pull the `turtle_generator` code into this notebook with an `import` command

# %%
# House cleaning part 1
from urllib.request import urlretrieve
(file, message) = urlretrieve('https://raw.githubusercontent.com/jbschroder/CS108/main/notebooks_turtle/turtle_generator.py', 'turtle_generator.py')
print("You downloaded the file " + file)

# House cleaning part 2
from turtle_generator import turtle_generator
# Out:
# You downloaded the file turtle_generator.py

# %% [markdown]
# ### Using what you learned in the lecture video, you will now experiment with more advanced if statements (conditionals)
#
# ### Task: Change `number` to other values (some negative, some positive, some 0).  Run the below cell each time you change `number`
#    - Observe the output, that is see what message is printed to the screen.
#    - Do you understand how your choice of `number` is controlling what is printed to the screen?

# %%
number = 5
if (not number == 0):
    print("This number is not zero!")
# Out:
# This number is not zero!

# %% [markdown]
# ### Task: Change `z` to other values (some negative, some positive, some 0).  Run the below cell each time you change `z`
#    - Observe the output, that is see what message is printed to the screen.
#    - Do you understand how your choice of `z` is controlling what is printed to the screen?

# %%
z = 5
if (not number >= 0):
    print("This number is NOT greater than zero!")
else:
    print("This number is greater than zero!")
# Out:
# This number is greater than zero!

# %% [markdown]
# ### You can also do conditionals with words and letters (that is, conditionals with strings)
#
# ### Task: Change the variable `direction` to other values (`'left'`, `'right'`, `'up'`, `'down'`)
#    - Observe the output, that is see what message is printed to the screen.
#    - Do you understand how your choice of `direction` is controlling what is printed to the screen?

# %%
direction = 'left'
if (direction == 'left'):
    print("We want to move LEFT") 
elif (direction == 'right'):
    print("We want to move RIGHT") 
elif (direction == 'up'):
    print("We want to move UP")
# Out:
# We want to move LEFT

# %% [markdown]
# ### Task: Go to the cell directly above, and add 2 new lines of code for moving down
# - You want to allow for `direction` to equal `down`
# - You'll want to take the two lines for `up`, copy and paste them, but change things so that `direction` can now equal `down`
#
# If you're unsure about any of this, please ask!

# %% [markdown]
# ### Now, we can get started with the turtle part of the lab!
#
# First, we create a new turtle
# - We use the _maze_ parameter again
# - Remember, that we can give `turtle_generator()` values inside the parentheses that tell `turtle_generator()` what to do
# - This is the essence of a **parameter**, values that you give something (like `turtle_generator()`) that tell it what to do
#
# Second, at the bottom of the cell, we take a look at our turtle and find that it's at location `(0,0)`, with a simple maze and pond

# %%
my_maze = 1
turtle = turtle_generator( maze_number=my_maze )

turtle.show_starting_position()

# %% [markdown]
# ### Next, we have to tell our turtle to get ready for a trip with `turtle.start_new_journey()`

# %%
turtle.start_new_journey()

# %% [markdown]
# ### For the turtle portion of the lab, we will now use conditionals to control the turtle movement
#
#
# ### Task:  Run the below two cells
# - Make sure you run both the cell with `direction = ...` and the cell with  `turtle.watch_me_move()`
#
#
# #### What happens?  Why does the turtle move one square to the right?

# %%
direction = 'right'
if (direction == 'left'):
    turtle.move_left()
elif (direction == 'right'):
    turtle.move_right()

# %%
turtle.watch_me_move()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgf520351c7e8f48d79f0d6ede3316a77d">
#   <div class="anim-controls">
#     <input id="_anim_sliderf520351c7e8f48d79f0d6ede3316a77d" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animf520351c7e8f48d79f0d6ede3316a77d.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animf520351c7e8f48d79f0d6ede3316a77d.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animf520351c7e8f48d79f0d6ede3316a77d.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animf520351c7e8f48d79f0d6ede3316a77d.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animf520351c7e8f48d79f0d6ede3316a77d.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animf520351c7e8f48d79f0d6ede3316a77d.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animf520351c7e8f48d79f0d6ede3316a77d.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animf520351c7e8f48d79f0d6ede3316a77d.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animf520351c7e8f48d79f0d6ede3316a77d.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animf520351c7e8f48d79f0d6ede3316a77d.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectf520351c7e8f48d79f0d6ede3316a77d"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_f520351c7e8f48d79f0d6ede3316a77d"
#              checked>
#       <label for="_anim_radio1_f520351c7e8f48d79f0d6ede3316a77d">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_f520351c7e8f48d79f0d6ede3316a77d"
#              >
#       <label for="_anim_radio2_f520351c7e8f48d79f0d6ede3316a77d">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_f520351c7e8f48d79f0d6ede3316a77d"
#              >
#       <label for="_anim_radio3_f520351c7e8f48d79f0d6ede3316a77d">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf520351c7e8f48d79f0d6ede3316a77d";
#     var slider_id = "_anim_sliderf520351c7e8f48d79f0d6ede3316a77d";
#     var loop_select_id = "_anim_loop_selectf520351c7e8f48d79f0d6ede3316a77d";
#     var frames = new Array(4);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjYuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy89olMNAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAA4R0lEQV

# %% [markdown]
# ### Next, we will restart our journey, which deletes all the previous moves

# %%
turtle.start_new_journey()

# %% [markdown]
# ### Task 1:  Add four new lines of code below to allow your turtle to go `down` and `up`
# - You can copy the two lines for going `left` and then modify for going `down`
# - Repeat for going `up`
#
# ### Task 2: Run the below cell multiple times, changing `direction` to direction your turtle through the maze
# - Each time you run the cell, you will generate a new animation with one new move

# %%
direction = 'right'
if (direction == 'left'):
    turtle.move_left()
elif (direction == 'right'):
    turtle.move_right()

turtle.watch_me_move()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img8c4e9b4d26094fe8a7d42ef79fd650f5">
#   <div class="anim-controls">
#     <input id="_anim_slider8c4e9b4d26094fe8a7d42ef79fd650f5" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim8c4e9b4d26094fe8a7d42ef79fd650f5.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim8c4e9b4d26094fe8a7d42ef79fd650f5.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim8c4e9b4d26094fe8a7d42ef79fd650f5.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim8c4e9b4d26094fe8a7d42ef79fd650f5.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim8c4e9b4d26094fe8a7d42ef79fd650f5.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim8c4e9b4d26094fe8a7d42ef79fd650f5.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim8c4e9b4d26094fe8a7d42ef79fd650f5.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim8c4e9b4d26094fe8a7d42ef79fd650f5.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim8c4e9b4d26094fe8a7d42ef79fd650f5.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim8c4e9b4d26094fe8a7d42ef79fd650f5.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select8c4e9b4d26094fe8a7d42ef79fd650f5"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_8c4e9b4d26094fe8a7d42ef79fd650f5"
#              checked>
#       <label for="_anim_radio1_8c4e9b4d26094fe8a7d42ef79fd650f5">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_8c4e9b4d26094fe8a7d42ef79fd650f5"
#              >
#       <label for="_anim_radio2_8c4e9b4d26094fe8a7d42ef79fd650f5">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_8c4e9b4d26094fe8a7d42ef79fd650f5"
#              >
#       <label for="_anim_radio3_8c4e9b4d26094fe8a7d42ef79fd650f5">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img8c4e9b4d26094fe8a7d42ef79fd650f5";
#     var slider_id = "_anim_slider8c4e9b4d26094fe8a7d42ef79fd650f5";
#     var loop_select_id = "_anim_loop_select8c4e9b4d26094fe8a7d42ef79fd650f5";
#     var frames = new Array(7);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjYuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy89olMNAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAA4R0lEQV

# %% [markdown]
# ### Advanced Task
# - Repeat all of the above tasks, but for `my_maze = 2`
